# %%
import pandas as pd

# %%
MAIN_DATA = pd.read_csv("/content/programming_basics21112024 (1).csv")

# %%
df = MAIN_DATA.copy()

# %%
df

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()

# %%
df[["Name", "Age"]]

# %%
type(df)

# %%
type(df["Name"])

# %%
values = [4, 5, 6]
indexes = ["a", "b", "c"]

# %%
series = pd.Series(values, indexes)

# %%
series
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
type(series)

# %%
series["b"]
# Out:
# 5

# %%
series[0:3:2]
# Out:
# a    4
# c    6
# dtype: int64

# %%
series.sort_values(ascending = False)
# Out:
# c    6
# b    5
# a    4
# dtype: int64

# %%
df_test = pd.DataFrame({"first_col" : [1 ,2, 3], "second_col" : [4, 5, 6]}, ["a", "b", "c"])

# %%
df_test

# %%
type(df_test)

# %%
df_test
# Out:
#    first_col  second_col
# a          1           4
# b          2           5
# c          3           6

# %%
# .iloc[row_index(es), column_index(es)]

# %%
df_test.iloc[1, 1]
# Out:
# 5

# %%
df_test.iloc[0:3, 0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: first_col, dtype: int64

# %%
df_test.iloc[0, 0:2]
# Out:
# first_col     1
# second_col    4
# Name: 0, dtype: int64

# %%
df_test.iloc[0:10, 0:3]
# Out:
#    first_col  second_col
# a          1           4
# b          2           5
# c          3           6

# %%
df_test.loc[["a", "b"], "first_col"]
# Out:
# a    1
# b    2
# Name: first_col, dtype: int64

# %%
df_test
# Out:
#    first_col  second_col
# a          1           4
# b          2           5
# c          3           6

# %%
df_test["third_col"] = ["Patryk", "Ola", "Ala"]

# %%
df_test

# %%
del(df_test["third_col"])

# %%
df_test
# Out:
#    first_col  second_col
# a          1           4
# b          2           5
# c          3           6

# %%
#DATA FILTERING

df_test[df_test["first_col"] > 1]
# Out:
#    first_col  second_col
# b          2           5
# c          3           6

# %%
#ITERATION

for elem in df_test:
  print(elem)
# Out:
# first_col
# second_col

# %%
for i, row in df_test.iterrows():
  print(i, row)

#NAH
# Out:
# a first_col     1
# second_col    4
# Name: a, dtype: int64
# b first_col     2
# second_col    5
# Name: b, dtype: int64
# c first_col     3
# second_col    6
# Name: c, dtype: int64

# %%
test_list = [1, 2, 3]

# %%
for elem in test_list:
  print(elem)
# Out:
# 1
# 2
# 3

# %%
#LIST COMPREHENSION

[elem + 1 for elem in test_list]
# Out:
# [2, 3, 4]

# %%
for elem in test_list:
  print(elem + 1)
# Out:
# 2
# 3
# 4

# %%
df_test
# Out:
#    first_col  second_col
# a          1           4
# b          2           5
# c          3           6

# %%
[elem + 1 for elem in df_test["first_col"]]
# Out:
# [2, 3, 4]

# %%
df_test["first_col"] = [elem + 1 for elem in df_test["first_col"]]

# %%
df_test
# Out:
#    first_col  second_col  third_col
# a          2           4          2
# b          3           5          3
# c          4           6          4

# %%
df_test["fourth_col"] = ["Patryk", "Ola", 'Ala']

# %%
df_test
# Out:
#    first_col  second_col  third_col fourth_col
# a          2           4          2     Patryk
# b          3           5          3        Ola
# c          4           6          4        Ala

# %%
df_test["fifth_col"] = [elem.replace("a", "b") for elem in df_test["fourth_col"]]

# %%
df_test
# Out:
#    first_col  second_col  third_col fourth_col fifth_col
# a          2           4          2     Patryk    Pbtryk
# b          3           5          3        Ola       Olb
# c          4           6          4        Ala       Alb

# %%
def add(num1, num2):
  return num1 + num2

# %%
add(2, 3)
# Out:
# 5

# %%
#Anononymous functions

#LAMBDA FUNCTIONS

# %%
add2 = lambda x, y: x + y

# %%
add2(2, 3)
# Out:
# 5

# %%
square = lambda x: x ** 2

# %%
square(4)
# Out:
# 16

# %%
numbers = [1, 2, 3, 4]

result = list(map(lambda x: x ** 2, numbers))

# %%
result
# Out:
# [100, 4, 9, 16]

# %%
numbers
# Out:
# [1, 2, 3, 4]

# %%
def is_even(number):
  if number % 2 == 0:
    return "Even"
  else:
    return "Odd"

# %%
even = list(filter(lambda x: x % 2 == 0, numbers))

# %%
even
# Out:
# [2, 4]

# %%
import pandas as pd

# %%
data = pd.Series([1, 2, 3, 4])

# %%
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
def double(num1):
  return num1 * 2

# %%
doubled = data.apply(lambda x: x * 2)

# %%
doubled
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
x1 = data.apply(lambda x: "Even" if x % 2 == 0 else "Odd")

# %%
x1
# Out:
# 0     Odd
# 1    Even
# 2     Odd
# 3    Even
# dtype: object

# %%
df = pd.DataFrame({"A" : [1, 2, 3], "B" : [4, 5, 6]})

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df["A_squared"] = df["A"].apply(lambda x: x ** 2)

# %%
df
# Out:
#    A  B  A_squared
# 0  1  4          1
# 1  2  5          4
# 2  3  6          9

# %%
df["Sum"] = df.apply(lambda row: row["A"] + row["B"], axis = 1)

# %%
df
# Out:
#    A  B  A_squared  Sum
# 0  1  4          1    5
# 1  2  5          4    7
# 2  3  6          9    9
